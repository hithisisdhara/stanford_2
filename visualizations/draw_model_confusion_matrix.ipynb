# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [[0.94,0.06], 
        [0.95,0.05]]
df_cm = pd.DataFrame(array, index = [i for i in ['positive','negative']],
                  columns = [i for i in ['true','false']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)

# %%
plt.show()

# %%
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('2deep_confusion_data.txt')
df
# Out:
#    epoch  true_neg  false_neg  true_pos  false_pos
# 0      1  0.927406   0.072594  0.546614   0.453386
# 1      2  0.890452   0.109548  0.963234   0.036766
# 2      3  0.986494   0.013506  0.964735   0.035265
# 3      4  0.992497   0.007503  0.983680   0.016320
# 4      5  0.996624   0.003376  0.996248   0.003752
# 5      6  0.994935   0.005065  0.999812   0.000188
# 6      7  0.998124   0.001876  0.999062   0.000938
# 7      8  0.999250   0.000750  1.000000   0.000000
# 8      9  1.000000   0.000000  1.000000   0.000000

# %%
type(df.as_matrix())
# Out:
# numpy.ndarray

# %%
array = [[0.927405740011255, 0.07259425998874508,0.5466141436878634, 0.45338585631213657],
[0.890452072781842, 0.10954792721815794,0.9632339148377416, 0.03676608516225849],
[0.9864940911648846, 0.013505908835115363,0.9647345713749765, 0.03526542862502345],
[0.9924967173138248, 0.007503282686175202,0.983680360157569, 0.016319639842431063],
[0.9966235227912211, 0.0033764772087788407,0.9962483586569124, 0.003751641343087601],
[0.9949352841868317, 0.005064715813168261,0.9998124179328456, 0.00018758206715438003],
[0.9981241793284562, 0.0018758206715438004,0.999062089664228, 0.0009379103357719002],
[0.9992496717313825, 0.0007503282686175201,1.0, 0.0],
[1.0, 0.0,1.0, 0.0]]
df_cm = pd.DataFrame(array, index = [1,2,3,4,5,6,7,8,9],
                  columns = [i for i in ['true_neg','false_neg','true_pos','false_pos']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.show()

# %%
array = [[92.74, 7.25,54.66, 45.33],
[89.04, 10.95,96.32, 3.67],
[98.64, 1.35,96.47, 3.52],
[99.24, 0.75,98.36, 1.63],
[99.66, 0.33,99.62, 0.37],
[99.49, 0.50,99.98, 0.01],
[99.81, 0.18,99.90, 0.09],
[99.92, 0.07,1.0, 0.0],
[1.0, 0.0,1.0, 0.0]]
df_cm = pd.DataFrame(array, index = [1,2,3,4,5,6,7,8,9],
                  columns = [i for i in ['true_neg','false_neg','true_pos','false_pos']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)

# %%
plt.show()

# %%
array = [[0.7794034890264491, 0.22059651097355093,0.8413055711873945, 0.1586944288126055],
[0.9289063965484899, 0.07109360345151003,0.9242168448696305, 0.07578315513036954],
[0.9694241230538361, 0.030575876946163948,0.9566685424873382, 0.04333145751266179],
[0.993059463515288, 0.006940536484712062,0.9829300318889514, 0.017069968111048585],
[0.994560120052523, 0.005439879947477021,0.9908084787094353, 0.009191521290564622],
[0.9964359407240668, 0.0035640592759332208,0.9964359407240668, 0.0035640592759332208],
[0.9986869255299193, 0.0013130744700806604,0.9983117613956106, 0.0016882386043894203],
[0.9992496717313825, 0.000750328268617520,0.9998124179328456, 0.00018758206715438003],
[0.9986869255299193, 0.0013130744700806604,0.9998124179328456, 0.00018758206715438003]]
df_cm = pd.DataFrame(array, index = [1,2,3,4,5,6,7,8,9],
                  columns = [i for i in ['true_neg','false_neg','true_pos','false_pos']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.show()
